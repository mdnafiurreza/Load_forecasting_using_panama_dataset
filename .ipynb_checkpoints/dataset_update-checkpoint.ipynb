# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

continuous_df = pd.read_csv('continuous dataset.csv')

continuous_df.head()
# Out:
#               datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc    W2M_toc  \
# 0  2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174  21.850546
# 1  2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418  22.166944
# 2  2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480  22.454911
# 3  2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273  22.110481
# 4  2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281  21.186089
#
#      T2M_san  QV2M_san   TQL_san    W2M_san    T2M_dav  QV2M_dav   TQL_dav  \
# 0  23.482446  0.017272  0.001855  10.328949  22.662134  0.016562  0.096100
# 1  23.399255  0.017265  0.001327  10.681517  22.578943  0.016509  0.087646
# 2  23.343530  0.017211  0.001428  10.874924  22.531030  0.016479  0.078735
# 3  23.238794  0.017128  0.002599  10.518620  22.512231  0.016487  0.068390
# 4  23.075403  0.017059  0.001729   9.733589  22.481653  0.016456  0.064362
#
#     W2M_dav  Holiday_ID  holiday  school
# ...

# %%
continuous_df['datetime'] = pd.to_datetime(continuous_df['datetime'])

continuous_df['year'] = continuous_df['datetime'].dt.year
yearly_avg = continuous_df.groupby('year')['nat_demand'].mean()

plt.figure(figsize=(10, 5))
plt.plot(yearly_avg.index, yearly_avg.values, marker='o')
plt.title('Average nat_demand Over the Years')
plt.xlabel('Year')
plt.ylabel('Average nat_demand')
plt.grid(True)
plt.tight_layout()
plt.savefig('nat_demand_over_years.png')

# %%
# Get average weather features
continuous_df['avg_T2M'] = continuous_df[['T2M_toc', 'T2M_san', 'T2M_dav']].mean(axis=1)
continuous_df['avg_QV2M'] = continuous_df[['QV2M_toc', 'QV2M_san', 'QV2M_dav']].mean(axis=1)
continuous_df['avg_TQL']  = continuous_df[['TQL_toc', 'TQL_san', 'TQL_dav']].mean(axis=1)
continuous_df['avg_W2M']  = continuous_df[['W2M_toc', 'W2M_san', 'W2M_dav']].mean(axis=1)

# Extract extra features
continuous_df['month']        = continuous_df['datetime'].dt.month
continuous_df['day_of_week']  = continuous_df['datetime'].dt.dayofweek 
continuous_df['hour_of_day']  = continuous_df['datetime'].dt.hour

# Define function for 4-season mapping
def get_season(month):
    if month in [12, 1, 2]:
        return 0  # Winter
    elif month in [3, 4, 5]:
        return 1  # Spring
    elif month in [6, 7, 8]:
        return 2  # Summer
    else:
        return 3  # Fall

# Add season column
continuous_df['season'] = continuous_df['month'].apply(get_season)

#Add weekend column
continuous_df['is_weekend'] = continuous_df['day_of_week'].apply(lambda x: 1 if x >= 5 else 0)

# Add 1-hour lag, 24-hour lag, and 1-week lag of `nat_demand`.

continuous_df['nat_demand_1hr_lag']    = continuous_df['nat_demand'].shift(1)
continuous_df['nat_demand_24hr_lag']   = continuous_df['nat_demand'].shift(24)
continuous_df['nat_demand_1week_lag']  = continuous_df['nat_demand'].shift(168)  # 24*7=168

continuous_df
# Out:
#                  datetime  nat_demand    T2M_toc  QV2M_toc   TQL_toc  \
# 0     2015-01-03 01:00:00    970.3450  25.865259  0.018576  0.016174
# 1     2015-01-03 02:00:00    912.1755  25.899255  0.018653  0.016418
# 2     2015-01-03 03:00:00    900.2688  25.937280  0.018768  0.015480
# 3     2015-01-03 04:00:00    889.9538  25.957544  0.018890  0.016273
# 4     2015-01-03 05:00:00    893.6865  25.973840  0.018981  0.017281
# ...                   ...         ...        ...       ...       ...
# 48043 2020-06-26 20:00:00   1128.5592  27.246545  0.020303  0.055511
# 48044 2020-06-26 21:00:00   1112.7488  27.099573  0.020395  0.053848
# 48045 2020-06-26 22:00:00   1081.5680  26.971155  0.020448  0.057251
# 48046 2020-06-26 23:00:00   1041.6240  26.867487  0.020464  0.064178
# 48047 2020-06-27 00:00:00   1013.5683  26.750330  0.020441  0.063965
#
#          W2M_toc    T2M_san  QV2M_san   TQL_san    W2M_san  ...   avg_TQL  \
# ...

# %%
# Final column ordering based on your updated instructions
final_columns = [
    'nat_demand','holiday','school','avg_T2M','avg_QV2M','avg_TQL','avg_W2M','season','month',
    'day_of_week','hour_of_day','is_weekend','year','nat_demand_1hr_lag','nat_demand_24hr_lag',
    'nat_demand_1week_lag',
]

# Prepare final dataframe
final_df = continuous_df[final_columns]

final_df = final_df.dropna().reset_index(drop=True)

final_df
# Out:
#        nat_demand  holiday  school    avg_T2M  avg_QV2M   avg_TQL    avg_W2M  \
# 0        906.9580        0       0  23.606704  0.016457  0.066152  13.350307
# 1        863.5135        0       0  23.544295  0.016462  0.063599  13.840689
# 2        848.4447        0       0  23.504724  0.016503  0.065865  14.086840
# 3        839.8821        0       0  23.527714  0.016571  0.062487  14.010866
# 4        847.1073        0       0  23.570540  0.016650  0.054685  13.581109
# ...           ...      ...     ...        ...       ...       ...        ...
# 47875   1128.5592        0       1  25.569462  0.019477  0.109314   4.574912
# 47876   1112.7488        0       1  25.448531  0.019449  0.121343   4.815926
# 47877   1081.5680        0       1  25.340946  0.019431  0.118347   5.153183
# 47878   1041.6240        0       1  25.242487  0.019408  0.108337   5.395190
# 47879   1013.5683        0       1  25.146163  0.019375  0.108917   5.423658
#
# ...

# %%
import seaborn as sns

# Compute correlation matrix for relevant features and target
corr_matrix = continuous_df[final_columns + ['nat_demand']].corr()

# Plot correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.savefig('correlation_matrix.png')
plt.show()

# %%
# Save to CSV 
final_df.to_csv('updated_dataset.csv', index=False)
